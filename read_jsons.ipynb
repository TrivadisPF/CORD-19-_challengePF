# %%
import os, json
import pandas as pd
    
# this is for appending the path header
path_header = r'CORD-19-research-challenge/2020-03-13/'
    
# this finds our json files
path_to_json = path_header + r'biorxiv_medrxiv/biorxiv_medrxiv'
path_to_json_2 = path_header + r"comm_use_subset/comm_use_subset"
path_to_json_3 = path_header + r"noncomm_use_subset/noncomm_use_subset"
path_to_json_4 = path_header + r"pmc_custom_license/pmc_custom_license"


list_of_jsons= [path_to_json, path_to_json_2, path_to_json_3,path_to_json_4]

json_files = []

for i in list_of_jsons:
    json_files.extend([os.path.join(i,pos_json) for pos_json in os.listdir(i) if pos_json.endswith('.json')])
    


#json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]


# here I define my pandas Dataframe with the columns I want to get from the json
jsons_data = pd.DataFrame(columns=['id', "title", "paper_abstract","paper_body"])

# we need both the json and an index number so use enumerate()

for index, js in enumerate(json_files):
    with open(js) as json_file:
        json_text = json.load(json_file)
        #print(json_text)
        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        title = json_text['metadata']['title']
        
        paper_id = json_text["paper_id"]
        
        #reduces the list only if there is content
        if json_text["abstract"] != []:
            paper_abstract = (json_text["abstract"])
        else:
            paper_abstract = (json_text["abstract"])
            
        #paper_abstract = (json_text["abstract"])
        paper_body = (json_text["body_text"])
        #print(title)
        # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [paper_id, title, paper_abstract, paper_body]


# now that we have the pertinent json data in our DataFrame let's look at it
#print(jsons_data)

# %%
jsons_data
# Out:
#                                              id  \
# 0      a22ceac8d5e1cfaf2e79557d3c794458d0e1cdbe
# 1      107f0d5a47f48f85d6645cac0e7008edc4d9d8cd
# 2      681c5099b2afb08fe5cb2f58d92e9c6e4873bec2
# 3      e4f66cfdaf836895e7d37941223f11ebc41dbb57
# 4      e350e1b4aab99c73d0e0d03121b50c059c04fd61
# ...                                         ...
# 13197  e29e17f37924d1d14edf56276a5dcca87851e62f
# 13198  6999b89c08c8a72fc0e86e78e4fd67666516a63a
# 13199  16b0744424f02e01fe2f01b3ea03e2862f1359fc
# 13200  2d102f7db396b4358f23cab728f3af3d8871c39c
# 13201  664563d8f7858aa1fe412414d4728b9243930e5a
#
#                                                    title  \
# 0                           23 of the 2019-nCoV sequence
# 1      Quantitative Delineation of Herpesviruses in B...
# 2      Geometric coupling of helicoidal ramps and cur...
# 3      PLANT-Dx: A Molecular Diagnostic for Point of ...
# 4      Novel Immunoglobulin Domain Proteins Provide I...
# ...                                                  ...
# 13197  HIV-1 Frameshift RNA-Targeted Triazoles Inhibi...
# 13198
# 13199  Reference sequence (RefSeq) database at NCBI: ...
# 13200       Protective Behavior and West Nile Virus Risk
# 13201  Respiratory Infection in Institutions during E...
#
#                                           paper_abstract  \
# 0      [{'text': 'In numerous instances, tracking the...
# 1      [{'text': 'Public health concerns about recent...
# 2      [{'text': 'Cellular membranes display an incre...
# 3      [{'text': 'Synthetic biology based diagnostic ...
# 4      [{'text': 'A novel coronavirus (SARS-CoV-2) is...
# ...                                                  ...
# 13197  [{'text': 'The HIV-1 frameshift-stimulating (F...
# 13198  [{'text': 'Nosocomial infections are a major w...
# 13199  [{'text': 'The RefSeq project at the National ...
# 13200                                                 []
# 13201                                                 []
#
#                                               paper_body
# 0      [{'text': '33 Meta-metagenomic searches allow ...
# 1      [{'text': 'Public health concerns associated w...
# 2      [{'text': 'Recent advances in microscopy, segm...
# 3      [{'text': 'Synthetic biology has recently cont...
# 4      [{'text': 'Nidoviruses are an ancient group of...
# ...                                                  ...
# 13197  [{'text': 'T here is a rapidly expanding recog...
# 13198  [{'text': 'Nosocomial infections (NIs) are a m...
# 13199  [{'text': 'For the past 15 years the National ...
# 13200  [{'text': 'We conducted a cross-sectional, hou...
# 13201  [{'text': 'large numbers of residents create a...
#
# [13202 rows x 4 columns]

# %%
title_1 = jsons_data.loc[1:1]['title'][1]

# %%
print(str(title_1))
# Out:
# Quantitative Delineation of Herpesviruses in Bats for use in Ecological Studies

# %%
Quantitative Delineation of Herpesviruses in Bats for use in Ecological Studies
