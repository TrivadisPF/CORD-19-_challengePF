# %%
import os, json
import pandas as pd
    

# this finds our json files
path_to_json = r'biorxiv_medrxiv\biorxiv_medrxiv'
path_to_json_2 = r"comm_use_subset\comm_use_subset"
path_to_json_3 = r"noncomm_use_subset\noncomm_use_subset"
path_to_json_4 = r"pmc_custom_license\pmc_custom_license"


list_of_jsons= [path_to_json, path_to_json_2, path_to_json_3,path_to_json_4]

json_files = []

for i in list_of_jsons:
    json_files.extend([os.path.join(i,pos_json) for pos_json in os.listdir(i) if pos_json.endswith('.json')])
    


#json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]


# here I define my pandas Dataframe with the columns I want to get from the json
jsons_data = pd.DataFrame(columns=['id', "title", "paper_abstract","paper_body"])

# we need both the json and an index number so use enumerate()

for index, js in enumerate(json_files):
    with open(js) as json_file:
        json_text = json.load(json_file)
        #print(json_text)
        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        title = json_text['metadata']['title']
        
        paper_id = json_text["paper_id"]
        
        #reduces the list only if there is content
        if json_text["abstract"] != []:
            paper_abstract = (json_text["abstract"])
        else:
            paper_abstract = (json_text["abstract"])
            
        #paper_abstract = (json_text["abstract"])
        paper_body = (json_text["body_text"])
        #print(title)
        # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [paper_id, title, paper_abstract, paper_body]


# now that we have the pertinent json data in our DataFrame let's look at it
#print(jsons_data)

# %%
jsons_data
# Out:
#                                              id  \
# 0      0015023cc06b5362d332b3baf348d11567ca2fbb
# 1      004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2      00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3      013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# 4      01d162d7fae6aaba8e6e60e563ef4c2fca7b0e18
# ...                                         ...
# 13197  ff365ebbc0fc55476886b0abd129e227c1f8a527
# 13198  ff7d49ac4008f60ef9c5a437e0d504dcefd1246f
# 13199  ffb381668d93248759ca3855425e05722cb9f562
# 13200  ffd3a93b927e221ded4cf76536ad31bef2c74b89
# 13201  ffe133ed880d6c77ae340c5374817232e21f8315
#
#                                                    title  \
# 0      The RNA pseudoknots in foot-and-mouth disease ...
# 1      Healthcare-resource-adjusted vulnerabilities t...
# 2      Real-time, MinION-based, amplicon sequencing f...
# 3      Assessing spread risk of Wuhan novel coronavir...
# 4      TWIRLS, an automated topic-wise inference meth...
# ...                                                  ...
# 13197                                  Article focus Hip
# 13198
# 13199
# 13200  Fatal Respiratory Infections Associated with R...
# 13201  Rational Design of Peptide Vaccines Against Mu...
#
#                                           paper_abstract  \
# 0      [{'text': 'word count: 194 22 Text word count:...
# 1                                                     []
# 2      [{'text': 'Infectious bronchitis (IB) causes s...
# 3      [{'text': 'Background: A novel coronavirus (20...
# 4      [{'text': 'Faced with the current large-scale ...
# ...                                                  ...
# 13197  [{'text': 'We report a systematic review and m...
# 13198                                                 []
# 13199                                                 []
# 13200  [{'text': 'During an outbreak of severe acute ...
# 13201  [{'text': 'Human papillomavirus (HPV) occurs i...
#
#                                               paper_body
# 0      [{'text': 'VP3, and VP0 (which is further proc...
# 1      [{'text': 'The 2019-nCoV epidemic has spread a...
# 2      [{'text': 'Infectious bronchitis (IB), which i...
# 3      [{'text': 'In December 2019, a cluster of pati...
# 4      [{'text': 'The sudden outbreak of the new coro...
# ...                                                  ...
# 13197  [{'text': 'Despite the fact that total hip art...
# 13198  [{'text': 'results of studies conducted in oth...
# 13199  [{'text': 'H uman coronaviruses (HCoVs) were f...
# 13200  [{'text': 'During an outbreak of severe acute ...
# 13201  [{'text': 'Certain types of cancers such as li...
#
# [13202 rows x 4 columns]
